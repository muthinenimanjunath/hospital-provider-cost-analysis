# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:\\Users\\manju\\OneDrive\\Desktop\\hospital-provider-cost-analysis\\flask\\data\\full_clustered_data.csv')
df.head(5)
# Out:
#    year state_code                      provider_type     ccn_facility_type  \
# 0  2012         NY  General Short-Term (includes CAH)   Short-Term Hospital
# 1  2012         IN  General Short-Term (includes CAH)   Short-Term Hospital
# 2  2012         SC               Psychiatric Hospital  Psychiatric Hospital
# 3  2012         IN               Psychiatric Hospital  Psychiatric Hospital
# 4  2012         AL  General Short-Term (includes CAH)   Short-Term Hospital
#
#    number_of_beds  total_bed_days_available  occupancy_rate  \
# 0            66.0                   23424.0        0.519244
# 1            66.0                   23424.0        0.519244
# 2            66.0                   23424.0        0.519244
# 3            66.0                   23424.0        0.519244
# 4            25.0                    2196.0        0.147692
#
#    total_discharges__v___xviii___xix___unknown_  \
# 0                                        1659.0
# ...

# %%
df_small = df[['Cluster', 'performance_score']]
df_small.to_csv("C:\\Users\\manju\\OneDrive\\Desktop\\hospital-provider-cost-analysis\\flask\\data\\clustered_data.csv", index=False)
